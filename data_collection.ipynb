# %% [markdown]
# # Data collection
# This file contains the code to collect a list of bird species from GBIF in the Ede area and download related bird song audio from Xeno Canto.
#
# GBIF.org (01 March 2023) GBIF Occurrence Download  https://doi.org/10.15468/dl.hzws49

# %%
from urllib.request import urlopen, urlretrieve, HTTPError, URLError
import os
import cgi
import duckdb
import pandas as pd
import logging

logging.basicConfig(filename='app.log', filemode='w', format='%(name)s - %(levelname)s - %(message)s')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Connect to Duck DB database file
con = duckdb.connect('data/db/collection.duckdb')

# %% [markdown]
# ## Functions

# %%
def fetch_bird_recordings(search_key, page_number, quality = 'A'):
    print(f'Fetching page {page_number} of {search_key}')
    url = f'https://xeno-canto.org/api/2/recordings?query=q:{quality}+{search_key}&page={page_number}'
    df = pd.read_json(url)
    current_page = df['page'].max()
    number_of_pages = df['numPages'].max()
    df = pd.DataFrame(df.recordings.values.tolist())
    
    con.sql(f'''
        INSERT INTO bird_recordings
        SELECT rec.*, '{search_key}' AS search_key
        FROM df AS rec
        WHERE rec.also = '[]'
    ''')
    
    if current_page < number_of_pages:
        fetch_bird_recordings(search_key, page_number + 1, quality)

# %%
def download_audio_data(dest_folder, file_url):
    try:
        remotefile = urlopen(file_url)
        contentdisposition = remotefile.info()['Content-Disposition']
        _, params = cgi.parse_header(contentdisposition)
        filename = f'data/audio/{dest_folder}/{params["filename"]}'

        os.makedirs(os.path.dirname(filename), exist_ok=True)
        urlretrieve(file_url, filename)

        print(f'Downloaded file: {filename}')
    except HTTPError as err:
        log_msg = f'Failed to download file at {file_url}, because of error code: {err.code}'
        print(log_msg)
        logging.error(log_msg)
    
    except URLError as err:
        log_msg = f'Failed to download file at {file_url}, because of error reason: {err.reason}'
        print(log_msg)
        logging.error(log_msg)

# %% [markdown]
# ## Pipeline

# %%
# Load observerd species based on GBIF data from Ede to a grouped pandas dataframe
df = pd.read_csv('data/csv/ede_bird_occurrence_pp.csv', sep='\t')
species = df[['species', 'individualCount']] \
            .fillna(1) \
            .groupby('species') \
            .agg(['sum','count']) \
            .pipe(lambda x: x.set_axis(x.columns.map('_'.join), axis=1)) \
            .reset_index()

# %%
# Store the dataframe data into the database
con.sql('''
    CREATE TABLE bird_observations_ede AS
    SELECT
        species,
        REPLACE(LOWER(species), ' ', '+') AS search_key,
        individualCount_sum               AS observation_sum,
        individualCount_count             AS observation_cnt
    FROM
        species
    ORDER BY
        individualCount_count DESC
''')

# %%
# Take the top 10 species and fetch their search keys to loop over
search_keys = con.sql('''
    SELECT search_key
    FROM bird_observations_ede
    LIMIT 50
''').fetchnumpy()

con.sql('''
    SELECT *
    FROM bird_observations_ede
    LIMIT 50
''').to_df()
# Out:
#                     species               search_key  observation_sum  \
# 0               Parus major              parus+major           1351.0
# 1         Fringilla coelebs        fringilla+coelebs           3835.0
# 2         Dryocopus martius        dryocopus+martius            493.0
# 3               Buteo buteo              buteo+buteo            548.0
# 4            Sitta europaea           sitta+europaea            559.0
# 5         Dendrocopos major        dendrocopos+major            483.0
# 6          Lanius excubitor         lanius+excubitor            344.0
# 7       Emberiza citrinella      emberiza+citrinella            670.0
# 8             Turdus merula            turdus+merula            503.0
# 9           Alauda arvensis          alauda+arvensis            784.0
# 10        Turdus philomelos        turdus+philomelos            513.0
# 11      Cyanistes caeruleus      cyanistes+caeruleus            682.0
# 12          Lanius collurio          lanius+collurio            432.0
# 13        Coturnix coturnix        coturnix+coturnix            328.0
# 14        Saxicola rubicola        saxicola+rubicola            366.0
# 15    Lophophanes cristatus    lophophanes+cristatus            392.0
# 16         Anthus trivialis         anthus+trivialis            300.0
# 17         Anthus pratensis         anthus+pratensis            611.0
# 18       Erithacus rubecula       erithacus+rubecula            247.0
# 19         Columba palumbus         columba+palumbus           1391.0
# 20   Phylloscopus collybita   phylloscopus+collybita            213.0
# 21           Ficedula parva           ficedula+parva            162.0
# 22      Aegithalos caudatus      aegithalos+caudatus            534.0
# 23    Certhia brachydactyla    certhia+brachydactyla            207.0
# 24        Turdus viscivorus        turdus+viscivorus            238.0
# 25      Garrulus glandarius      garrulus+glandarius            230.0
# 26         Sturnus vulgaris         sturnus+vulgaris           3927.0
# 27        Falco tinnunculus        falco+tinnunculus            139.0
# 28  Troglodytes troglodytes  troglodytes+troglodytes            138.0
# 29             Corvus corax             corvus+corax            345.0
# 30        Muscicapa striata        muscicapa+striata            120.0
# 31        Linaria cannabina        linaria+cannabina            250.0
# 32          Cuculus canorus          cuculus+canorus            110.0
# 33          Regulus regulus          regulus+regulus            393.0
# 34        Passer domesticus        passer+domesticus            403.0
# 35            Corvus corone            corvus+corone            141.0
# 36          Lullula arborea          lullula+arborea            109.0
# 37          Hirundo rustica          hirundo+rustica            564.0
# 38           Motacilla alba           motacilla+alba            124.0
# 39                Apus apus                apus+apus            561.0
# 40            Ardea cinerea            ardea+cinerea             75.0
# 41      Carduelis carduelis      carduelis+carduelis            213.0
# 42        Pyrrhula pyrrhula        pyrrhula+pyrrhula            110.0
# 43       Sylvia atricapilla       sylvia+atricapilla             87.0
# 44              Anser anser              anser+anser            812.0
# 45    Caprimulgus europaeus    caprimulgus+europaeus            112.0
# 46       Ficedula hypoleuca       ficedula+hypoleuca             52.0
# 47        Aquila chrysaetos        aquila+chrysaetos             42.0
# 48            Spinus spinus            spinus+spinus            473.0
# 49  Phoenicurus phoenicurus  phoenicurus+phoenicurus             41.0
#
#     observation_cnt
# 0               729
# 1               575
# 2               452
# 3               434
# 4               427
# 5               383
# 6               336
# 7               331
# 8               321
# 9               282
# 10              282
# 11              280
# 12              267
# 13              244
# 14              227
# 15              218
# 16              212
# 17              208
# 18              200
# 19              193
# 20              172
# 21              162
# 22              159
# 23              152
# 24              147
# 25              143
# 26              121
# 27              118
# 28              118
# 29              110
# 30               96
# 31               89
# 32               88
# 33               87
# 34               84
# 35               82
# 36               82
# 37               81
# 38               80
# 39               78
# 40               66
# 41               64
# 42               63
# 43               61
# 44               58
# 45               53
# 46               49
# 47               42
# 48               41
# 49               40

# %%
# Take the species that don't exist in the Google Model but do in the Edese bos area
search_keys = con.sql('''
    SELECT search_key
    FROM bird_observations_ede
    WHERE search_key IN ('galerida+cristata', 'picus+viridis', 'phasianus+colchicus')
''').fetchnumpy()

con.sql('''
    SELECT *
    FROM bird_observations_ede
    WHERE search_key IN ('galerida+cristata', 'picus+viridis', 'phasianus+colchicus')
''').to_df()
# Out:
#                species           search_key  observation_sum  observation_cnt
# 0    Galerida cristata    galerida+cristata              4.0                1
# 1        Picus viridis        picus+viridis             17.0               16
# 2  Phasianus colchicus  phasianus+colchicus             12.0               12

# %%
# Loop over search keys
for search_key in search_keys['search_key']:
    fetch_bird_recordings(search_key, 1, 'A')
# Out:
# Fetching page 1 of galerida+cristata
# Fetching page 1 of picus+viridis
# Fetching page 1 of phasianus+colchicus

# %%
con.sql('''
    SELECT search_key, COUNT(*) AS count
    FROM bird_recordings
    WHERE search_key IN ('galerida+cristata', 'picus+viridis', 'phasianus+colchicus')
    GROUP BY search_key
    ORDER BY count DESC
''').to_df()
# Out:
#             search_key  count
# 0        picus+viridis    256
# 1    galerida+cristata    199
# 2  phasianus+colchicus    139

# %%
df = con.sql('''
    SELECT REPLACE(search_key, '+', '_') AS dest_folder, file
    FROM bird_recordings
    WHERE search_key IN ('galerida+cristata', 'picus+viridis', 'phasianus+colchicus')
''').to_df()

# %%
df
# Out:
#              dest_folder                                    file
# 0      galerida_cristata  https://xeno-canto.org/803678/download
# 1      galerida_cristata  https://xeno-canto.org/798070/download
# 2      galerida_cristata  https://xeno-canto.org/793022/download
# 3      galerida_cristata  https://xeno-canto.org/792605/download
# 4      galerida_cristata  https://xeno-canto.org/792604/download
# ..                   ...                                     ...
# 589  phasianus_colchicus   https://xeno-canto.org/65778/download
# 590  phasianus_colchicus   https://xeno-canto.org/41223/download
# 591  phasianus_colchicus   https://xeno-canto.org/37452/download
# 592  phasianus_colchicus   https://xeno-canto.org/22692/download
# 593  phasianus_colchicus   https://xeno-canto.org/16976/download
#
# [594 rows x 2 columns]

# %%
for index, row in df.iterrows():
    download_audio_data(row['dest_folder'], row['file'])
# Out:
# Downloaded file: data/audio/galerida_cristata/XC803678 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC798070 - Crested Lark - Galerida cristata.wav
# Downloaded file: data/audio/galerida_cristata/XC793022 - Crested Lark - Galerida cristata.wav
# Downloaded file: data/audio/galerida_cristata/XC792605 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC792604 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC792542 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC792389 - Crested Lark - Galerida cristata.wav
# Downloaded file: data/audio/galerida_cristata/XC792388 - Crested Lark - Galerida cristata.wav
# Downloaded file: data/audio/galerida_cristata/XC782232 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC782230 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC782229 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC782148 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC781631 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC781590 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC781436 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC781435 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC781180 - Crested Lark - Galerida cristata.wav
# Downloaded file: data/audio/galerida_cristata/XC779816 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC779813 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC770177 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC770176 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC770175 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC770174 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC770096 - Crested Lark - Galerida cristata.wav
# Downloaded file: data/audio/galerida_cristata/XC769180 - Crested Lark - Galerida cristata carthaginis.wav
# Downloaded file: data/audio/galerida_cristata/XC738893 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC732859 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC732857 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC730442 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC730441 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC714560 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC712607 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC703074 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC702001 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC700169 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC699685 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC699134 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC694991 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC694990 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC694989 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC689198 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC688469 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC685218 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC676680 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC672478 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC664693 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC658028 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC658027 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC645977 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC643763 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC642690 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC633566 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC626257 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC626253 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC626252 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC626251 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC626250 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC621307 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC613811 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC613804 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC606875 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC590932 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC590930 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC590133 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/XC589789 - Crested Lark - Galerida cristata.mp3
# Downloaded file: data/audio/galerida_cristata/X
- Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC360686 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC357737 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC355268 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC339797 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC334955 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC330743 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC330742 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC330741 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC315805 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC309991 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC281836 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC266715 - Common Pheasant - Phasianus colchicus pallasi.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC266714 - Common Pheasant - Phasianus colchicus pallasi.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC266708 - Common Pheasant - Phasianus colchicus pallasi.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC243870 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC243602 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC205561 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC205559 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC204435 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC204259 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC197441 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC191317 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC191272 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC191271 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC185058 - Common Pheasant - Phasianus colchicus zerafschanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC185057 - Common Pheasant - Phasianus colchicus zerafschanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC185056 - Common Pheasant - Phasianus colchicus zerafschanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC185055 - Common Pheasant - Phasianus colchicus zerafschanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC183799 - Common Pheasant - Phasianus colchicus turcestanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC183797 - Common Pheasant - Phasianus colchicus turcestanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC183796 - Common Pheasant - Phasianus colchicus turcestanicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC182192 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC182191 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC181782 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC172951 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC163167 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC115583 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC113664 - Common Pheasant - Phasianus colchicus kiangsuensis.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC112465 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC99473 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC97310 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC93148 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC92929 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC92832 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC87165 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC83152 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC65778 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC41223 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC37452 - Common Pheasant - Phasianus colchicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC22692 - Common Pheasant - Phasianus colchicus mongolicus.mp3
# Downloaded file: data/audio/phasianus_colchicus/XC16976 - Common Pheasant - Phasianus colchicus.mp3

# %%
# con.sql('''
#     SELECT id
#     FROM bird_recordings
# ''').to_csv('data/csv/ids.csv')

# %% [markdown]
# ## Load eBird Taxonomy data and join it to our birds of interrest

# %%
# Load eBird Taxonomy
ebird = pd.read_excel('data/ebird_taxonomy_v2022.xlsx')
ebird[['SPECIES_CODE', 'SCI_NAME']]
# Out:
#       SPECIES_CODE                        SCI_NAME
# 0          ostric2                Struthio camelus
# 1          ostric3          Struthio molybdophanes
# 2           y00934  Struthio camelus/molybdophanes
# 3          grerhe1                  Rhea americana
# 4          lesrhe2                    Rhea pennata
# ...            ...                             ...
# 16855      slcgro1                Saltator grossus
# 16856      bltgro2            Saltator fuliginosus
# 16857      saltat1                    Saltator sp.
# 16858      passer1               Passeriformes sp.
# 16859        bird1                        Aves sp.
#
# [16860 rows x 2 columns]

# %%
# Get species that do not map to be able to create a manual mapping file
con.sql('''
    SELECT
        bo.*,
        eb.SPECIES_CODE AS ebird_code
    FROM
        bird_observations_ede AS bo
    LEFT JOIN
        ebird AS eb
    ON
        bo.search_key = LOWER(REPLACE(eb.SCI_NAME, ' ', '+'))
    WHERE
        eb.SPECIES_CODE IS NULL
    ORDER BY
        observation_cnt DESC
''').to_df()
# Out:
# 0    Phylloscopus sibillatrix
# 1            Coloeus monedula
# 2             Sylvia communis
# 3               Anas clypeata
# 4            Anas querquedula
# 5               Aquila clanga
# 6              Sylvia curruca
# Name: species, dtype: object

# %%
# Load Manual mapping
mmap = pd.read_excel('data/manual_mapping_ebird_gbif.xlsx')

# %%
mmap
# Out:
#   ebird_code               ebird_name                 gbif_name
# 0     woowar  Phylloscopus sibilatrix  Phylloscopus sibillatrix
# 1     eurjac          Corvus monedula          Coloeus monedula
# 2    grewhi1         Curruca communis           Sylvia communis
# 3     norsho         Spatula clypeata             Anas clypeata
# 4     gargan      Spatula querquedula          Anas querquedula
# 5    grseag1            Clanga clanga             Aquila clanga
# 6    sylvia1       Sylvia/Curruca sp.            Sylvia curruca

# %%
con.sql('DROP TABLE bird_observations_ede_sc')

# %%
con.sql('''
    CREATE TABLE bird_observations_ede_sc AS
    SELECT
        bo.*,
        COALESCE(eb.SPECIES_CODE, eb2.SPECIES_CODE) AS ebird_code_def
    FROM
        bird_observations_ede AS bo
    LEFT JOIN
        mmap as mp
    ON
        bo.species = mp.gbif_name
    LEFT JOIN
        ebird AS eb
    ON
        bo.search_key = LOWER(REPLACE(eb.SCI_NAME, ' ', '+'))
    LEFT JOIN
        ebird AS eb2
    ON
        mp.ebird_code = eb2.SPECIES_CODE
    WHERE
        ebird_code_def IS NOT NULL
    ORDER BY
        observation_cnt DESC
''')

# %%
con.sql('''
    SELECT *
    FROM bird_observations_ede_sc
    WHERE ebird_code_def = 'gargan'
''').to_df()
# Out:
#             species        search_key  observation_sum  observation_cnt  \
# 0  Anas querquedula  anas+querquedula              1.0                1
#
#   ebird_code_def
# 0         gargan

# %%
rs = pd.read_csv('data/result.csv')
rs
# Out:
#      frame     time    class  probability
# 0        0  0:00:00  martit2     0.366938
# 1        1  0:00:05  gretit1     0.266846
# 2        2  0:00:10   blutit     0.432775
# 3        3  0:00:15  shttre1     0.111287
# 4        4  0:00:20   blutit     0.634578
# ..     ...      ...      ...          ...
# 715    715  0:59:35  coatit2     0.660683
# 716    716  0:59:40  coatit2     0.194544
# 717    717  0:59:45  gretit1     0.277770
# 718    718  0:59:50   fieldf     0.215344
# 719    719  0:59:55   eurbla     0.439528
#
# [720 rows x 4 columns]

# %%
con.sql('''
    SELECT
        rs.class,
        bo.SCI_NAME,
        COUNT(*) AS aantal_obs
    FROM
        rs
    LEFT JOIN
        ebird AS bo
    ON
        rs.class = bo.SPECIES_CODE
    WHERE
        rs.probability > 0.7
    GROUP BY
        rs.class,
        bo.SCI_NAME
    ORDER BY
        aantal_obs DESC
''').to_df()
# Out:
#       class               SCI_NAME  aantal_obs
# 0   gretit1            Parus major          44
# 1   martit2      Poecile palustris          40
# 2   eurnut2         Sitta europaea          35
# 3   shttre1  Certhia brachydactyla          22
# 4    grswoo      Dendrocopos major          20
# 5   eurrob1     Erithacus rubecula           8
# 6   tawowl1            Strix aluco           4
# 7   miswoo1    Dendrocoptes medius           4
# 8    eurbla          Turdus merula           4
# 9    blutit    Cyanistes caeruleus           3
# 10   gwfgoo        Anser albifrons           2
# 11   pifgoo   Anser brachyrhynchus           2
# 12  spocra1        Porzana porzana           1

# %%
con.sql('''
    CREATE TABLE uncommon_obs_ede AS
    SELECT
        rs.*,
        CAST(rs.time AS TIME) - INTERVAL 5 SECOND AS time_m5,
        CAST(rs.time AS TIME) + INTERVAL 5 SECOND AS time_p5,
        bo.SCI_NAME,
    FROM
        rs
    LEFT JOIN
        ebird AS bo
    ON
        rs.class = bo.SPECIES_CODE
    WHERE
        rs.probability > 0.5 AND
        rs.class NOT IN (
            SELECT ebird_code_def
            FROM bird_observations_ede_sc
        )
    ORDER BY
        rs.frame;
''')

# %%
con.sql('''
    COPY
        uncommon_obs_ede
    TO
        'data/csv/species_detected_not_in_gbif.csv' (HEADER, DELIMITER ';');
''')

# %%
con.sql('''
    SELECT
        species,
        ebird_code_def,
        SUM(observation_sum) AS observation_sum,
        SUM(observation_cnt) AS observation_cnt
    FROM
        bird_observations_ede_sc
    GROUP BY
        species,
        ebird_code_def
    ORDER BY
        observation_cnt DESC;
''').to_df()
# Out:
#                     species ebird_code_def  observation_sum  observation_cnt
# 0               Parus major        gretit1           1351.0            729.0
# 1         Fringilla coelebs         comcha           3835.0            575.0
# 2         Dryocopus martius        blawoo1            493.0            452.0
# 3               Buteo buteo        combuz1            548.0            434.0
# 4            Sitta europaea        eurnut2            559.0            427.0
# ..                      ...            ...              ...              ...
# 140   Luscinia megarhynchos        comnig1              1.0              1.0
# 141     Ficedula albicollis        colfly1              1.0              1.0
# 142        Saxicola rubetra        whinch1              1.0              1.0
# 143   Plectrophenax nivalis         snobun              1.0              1.0
# 144  Emberiza leucocephalos         pinbun              1.0              1.0
#
# [145 rows x 4 columns]

# %%
con.sql('''
    COPY (
        SELECT
            species,
            ebird_code_def,
            SUM(observation_sum) AS observation_sum,
            SUM(observation_cnt) AS observation_cnt
        FROM
            bird_observations_ede_sc
        GROUP BY
            species,
            ebird_code_def
        ORDER BY
            observation_cnt DESC
    )
    TO
        'data/csv/gbif_species_ede.csv' (HEADER, DELIMITER ';');
''')

# %% [markdown]
# ## Load meteo data

# %%
rain = pd.read_excel(r'data/rain_per_hour_fixed.xlsx')

# %%
con.sql('''
    DROP TABLE rain_per_hour
''')

# %%
con.sql('''
    CREATE TABLE rain_per_hour AS
    SELECT
        *
    FROM
        rain;
''')

# %% [markdown]
# ## Experimental code snipets
# These snipets were used to experiment and kept for future use.

# %%
search_key = 'parus+major'
page_number = 1
url = f'https://xeno-canto.org/api/2/recordings?query=q:A+{search_key}&page={page_number}'

# urlretrieve(url, f'data/json/{search_key}_{page_number}.json')
# Out:
# ('data/json/parus+major_1.json', <http.client.HTTPMessage at 0x172e16ac0>)

# %%
# Collect recordings
df = pd.read_json(url)
current_page = df['page'].max()
number_of_pages = df['numPages'].max()
df = pd.DataFrame(df.recordings.values.tolist())

# %%
# Download audio file
dest_folder = 'test'
file_url = 'https://xeno-canto.org/783426/download'

remotefile = urlopen(file_url)
contentdisposition = remotefile.info()['Content-Disposition']
_, params = cgi.parse_header(contentdisposition)
filename = f'data/audio/{dest_folder}/{params["filename"]}'

os.makedirs(os.path.dirname(filename), exist_ok=True)
urlretrieve(file_url, filename)
# Out:
# ('data/audio/test/XC783426 - Australian Masked Owl - Tyto novaehollandiae castanops.wav',
#  <http.client.HTTPMessage at 0x1777feca0>)

# %%
log_msg = f'Test message'
print(log_msg)
logging.error(log_msg)
# Out:
# Test message

# %%
# con.sql(f'''
#     CREATE TABLE bird_recordings AS
#     SELECT rec.*, '{search_key}' AS search_key
#     FROM df_rec AS rec
#     WHERE also = '[]'
# ''')

# con.sql('''
#     DELETE
#     FROM bird_recordings
# ''')

# %%
con.sql('''
    DELETE
    FROM bird_recordings
    WHERE search_key IN ('galerida+cristata', 'picus+viridis', 'phasianus+colchicus');
''')

# %%
con.close()
